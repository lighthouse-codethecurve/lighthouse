# %% [markdown]
# # 可汗学院的数据汇总

# %%
import pandas as pd
import numpy as np

# %%
课程ID 、课程名称、年级、科目、课程介绍、内容标签、链接
备用标签：是否有老师出镜、资源的类型（视频文档工具）、是否免费、是否需要登录
这里好像只有数学的才是按照年级去分类的，但是别的科目并没有按照这个方式去分类
或者就是主要是数学、科学、计算机、语文（humanities）

# %%
All_data = pd.read_excel('Save_Excel.xlsx','page_1',index_col=0)
#tab_data = pd.read_excel('Save_Excel.xlsx','level',index_col=0)

# %%
# 取出需要的几个主要学科
subject = ['math','science','computing','humanities']

# %%
all_final_data = []
for one_s in subject:
    one_s_data = All_data.loc[All_data[one_s]==1].replace(0,np.NAN).dropna(axis=1,how='all')
    one_s_data = one_s_data.drop([one_s],axis=1)
    for i in one_s_data.index:
        one_fina_s = []
        one_c = one_s_data.loc[i]
        content_label = list(one_c[1:-1][one_c[1:-1]==1].index)
        content_label = ','.join(content_label)
        one_grade = np.NAN
        if '-math' in content_label:
            grade = content_label.split('-math')[0]
            if grade == 'cc-1st-grade':
                one_grade = 1
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
            elif grade == 'cc-third-grade':
                one_grade = 3
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
            elif grade == 'cc-fourth-grade':
                one_grade = 4
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
            elif grade == 'cc-fifth-grade':
                one_grade = 5
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
            elif grade == 'cc-sixth-grade':
                one_grade = 6
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
            elif grade == 'cc-seventh-grade':
                one_grade = 7
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
            elif grade == 'cc-eighth-grade':
                one_grade = 8    
                one_fina_s.append([one_c['course'],one_grade,one_s,content_label,np.NAN,one_c['website']])
        all_final_data.extend(one_fina_s)

# %%
final_data = pd.DataFrame(all_final_data,columns=['course_name','course_garde','subject','content_label','course_introduction','course_url'])
final_data.head()
# Out:
#                              course_name  course_garde subject  \
# 0                            Place value             1    math
# 1        Measurement, data, and geometry             1    math
# 2                Intro to multiplication             3    math
# 3                 1-digit multiplication             3    math
# 4  Addition, subtraction, and estimation             3    math
#
#          content_label  course_introduction  \
# 0    cc-1st-grade-math                  NaN
# 1    cc-1st-grade-math                  NaN
# 2  cc-third-grade-math                  NaN
# 3  cc-third-grade-math                  NaN
# 4  cc-third-grade-math                  NaN
#
#                                           course_url
# 0  https://www.khanacademy.org/math/cc-1st-grade-...
# 1  https://www.khanacademy.org/math/cc-1st-grade-...
# 2  https://www.khanacademy.org/math/cc-third-grad...
# 3  https://www.khanacademy.org/math/cc-third-grad...
# 4  https://www.khanacademy.org/math/cc-third-grad...

# %%
final_data
# Out:
#                                       course_name  course_garde subject  \
# 0                                     Place value             1    math
# 1                 Measurement, data, and geometry             1    math
# 2                         Intro to multiplication             3    math
# 3                          1-digit multiplication             3    math
# 4           Addition, subtraction, and estimation             3    math
# 5                               Intro to division             3    math
# 6                            Understand fractions             3    math
# 7    Equivalent fractions and comparing fractions             3    math
# 8           More with multiplication and division             3    math
# 9         Arithmetic patterns and problem solving             3    math
# 10                                 Quadrilaterals             3    math
# 11                                           Area             3    math
# 12                                      Perimeter             3    math
# 13                                           Time             3    math
# 14                   Represent and interpret data             3    math
# 15                    Multiply by 1-digit numbers             4    math
# 16                    Multiply by 2-digit numbers             4    math
# 17                                       Division             4    math
# 18                Factors, multiples and patterns             4    math
# 19                     Add and subtract fractions             4    math
# 20                             Multiply fractions             4    math
# 21                            Understand decimals             4    math
# 22                                  Plane figures             4    math
# 23                               Measuring angles             4    math
# 24                             Area and perimeter             4    math
# 25                           Units of measurement             4    math
# 26                            Decimal place value             5    math
# 27                                   Add decimals             5    math
# 28                              Subtract decimals             5    math
# 29        Multi-digit multiplication and division             5    math
# 30                               Divide fractions             5    math
# 31                              Multiply decimals             5    math
# 32                                Divide decimals             5    math
# 33                                  Powers of ten             5    math
# 34                                         Volume             5    math
# 35                               Coordinate plane             5    math
# 36                             Algebraic thinking             5    math
# 37                    Converting units of measure             5    math
# 38                                     Line plots             5    math
# 39                           Properties of shapes             5    math
# 40               Ratios, rates, &amp; percentages             6    math
# 41                          Arithmetic operations             6    math
# 42                          Properties of numbers             6    math
# 43                    Variables &amp; expressions             6    math
# 44      Equations &amp; inequalities introduction             6    math
# 45                            Data and statistics             6    math
# 46     Negative numbers: addition and subtraction             7    math
# 47  Negative numbers: multiplication and division             7    math
# 48         Fractions, decimals, &amp; percentages             7    math
# 49         Rates &amp; proportional relationships             7    math
# 50     Expressions, equations, &amp; inequalities             7    math
# 51                     Statistics and probability             7    math
# 52                         Numbers and operations             8    math
# 53             Solving equations with one unknown             8    math
# 54                 Linear equations and functions             8    math
# 55                      Geometric transformations             8    math
# 56                              Data and modeling             8    math
#
#             content_label  course_introduction  \
# 0       cc-1st-grade-math                  NaN
# 1       cc-1st-grade-math                  NaN
# 2     cc-third-grade-math                  NaN
# 3     cc-third-grade-math                  NaN
# 4     cc-third-grade-math                  NaN
# 5     cc-third-grade-math                  NaN
# 6     cc-third-grade-math                  NaN
# 7     cc-third-grade-math                  NaN
# 8     cc-third-grade-math                  NaN
# 9     cc-third-grade-math                  NaN
# 10    cc-third-grade-math                  NaN
# 11    cc-third-grade-math                  NaN
# 12    cc-third-grade-math                  NaN
# 13    cc-third-grade-math                  NaN
# 14    cc-third-grade-math                  NaN
# 15   cc-fourth-grade-math                  NaN
# 16   cc-fourth-grade-math                  NaN
# 17   cc-fourth-grade-math                  NaN
# 18   cc-fourth-grade-math                  NaN
# 19   cc-fourth-grade-math                  NaN
# 20   cc-fourth-grade-math                  NaN
# 21   cc-fourth-grade-math                  NaN
# 22   cc-fourth-grade-math                  NaN
# 23   cc-fourth-grade-math                  NaN
# 24   cc-fourth-grade-math                  NaN
# 25   cc-fourth-grade-math                  NaN
# 26    cc-fifth-grade-math                  NaN
# 27    cc-fifth-grade-math                  NaN
# 28    cc-fifth-grade-math                  NaN
# 29    cc-fifth-grade-math                  NaN
# 30    cc-fifth-grade-math                  NaN
# 31    cc-fifth-grade-math                  NaN
# 32    cc-fifth-grade-math                  NaN
# 33    cc-fifth-grade-math                  NaN
# 34    cc-fifth-grade-math                  NaN
# 35    cc-fifth-grade-math                  NaN
# 36    cc-fifth-grade-math                  NaN
# 37    cc-fifth-grade-math                  NaN
# 38    cc-fifth-grade-math                  NaN
# 39    cc-fifth-grade-math                  NaN
# 40    cc-sixth-grade-math                  NaN
# 41    cc-sixth-grade-math                  NaN
# 42    cc-sixth-grade-math                  NaN
# 43    cc-sixth-grade-math                  NaN
# 44    cc-sixth-grade-math                  NaN
# 45    cc-sixth-grade-math                  NaN
# 46  cc-seventh-grade-math                  NaN
# 47  cc-seventh-grade-math                  NaN
# 48  cc-seventh-grade-math                  NaN
# 49  cc-seventh-grade-math                  NaN
# 50  cc-seventh-grade-math                  NaN
# 51  cc-seventh-grade-math                  NaN
# 52   cc-eighth-grade-math                  NaN
# 53   cc-eighth-grade-math                  NaN
# 54   cc-eighth-grade-math                  NaN
# 55   cc-eighth-grade-math                  NaN
# 56   cc-eighth-grade-math                  NaN
#
#                                            course_url
# 0   https://www.khanacademy.org/math/cc-1st-grade-...
# 1   https://www.khanacademy.org/math/cc-1st-grade-...
# 2   https://www.khanacademy.org/math/cc-third-grad...
# 3   https://www.khanacademy.org/math/cc-third-grad...
# 4   https://www.khanacademy.org/math/cc-third-grad...
# 5   https://www.khanacademy.org/math/cc-third-grad...
# 6   https://www.khanacademy.org/math/cc-third-grad...
# 7   https://www.khanacademy.org/math/cc-third-grad...
# 8   https://www.khanacademy.org/math/cc-third-grad...
# 9   https://www.khanacademy.org/math/cc-third-grad...
# 10  https://www.khanacademy.org/math/cc-third-grad...
# 11  https://www.khanacademy.org/math/cc-third-grad...
# 12  https://www.khanacademy.org/math/cc-third-grad...
# 13  https://www.khanacademy.org/math/cc-third-grad...
# 14  https://www.khanacademy.org/math/cc-third-grad...
# 15  https://www.khanacademy.org/math/cc-fourth-gra...
# 16  https://www.khanacademy.org/math/cc-fourth-gra...
# 17  https://www.khanacademy.org/math/cc-fourth-gra...
# 18  https://www.khanacademy.org/math/cc-fourth-gra...
# 19  https://www.khanacademy.org/math/cc-fourth-gra...
# 20  https://www.khanacademy.org/math/cc-fourth-gra...
# 21  https://www.khanacademy.org/math/cc-fourth-gra...
# 22  https://www.khanacademy.org/math/cc-fourth-gra...
# 23  https://www.khanacademy.org/math/cc-fourth-gra...
# 24  https://www.khanacademy.org/math/cc-fourth-gra...
# 25  https://www.khanacademy.org/math/cc-fourth-gra...
# 26  https://www.khanacademy.org/math/cc-fifth-grad...
# 27  https://www.khanacademy.org/math/cc-fifth-grad...
# 28  https://www.khanacademy.org/math/cc-fifth-grad...
# 29  https://www.khanacademy.org/math/cc-fifth-grad...
# 30  https://www.khanacademy.org/math/cc-fifth-grad...
# 31  https://www.khanacademy.org/math/cc-fifth-grad...
# 32  https://www.khanacademy.org/math/cc-fifth-grad...
# 33  https://www.khanacademy.org/math/cc-fifth-grad...
# 34  https://www.khanacademy.org/math/cc-fifth-grad...
# 35  https://www.khanacademy.org/math/cc-fifth-grad...
# 36  https://www.khanacademy.org/math/cc-fifth-grad...
# 37  https://www.khanacademy.org/math/cc-fifth-grad...
# 38  https://www.khanacademy.org/math/cc-fifth-grad...
# 39  https://www.khanacademy.org/math/cc-fifth-grad...
# 40  https://www.khanacademy.org/math/cc-sixth-grad...
# 41  https://www.khanacademy.org/math/cc-sixth-grad...
# 42  https://www.khanacademy.org/math/cc-sixth-grad...
# 43  https://www.khanacademy.org/math/cc-sixth-grad...
# 44  https://www.khanacademy.org/math/cc-sixth-grad...
# 45  https://www.khanacademy.org/math/cc-sixth-grad...
# 46  https://www.khanacademy.org/math/cc-seventh-gr...
# 47  https://www.khanacademy.org/math/cc-seventh-gr...
# 48  https://www.khanacademy.org/math/cc-seventh-gr...
# 49  https://www.khanacademy.org/math/cc-seventh-gr...
# 50  https://www.khanacademy.org/math/cc-seventh-gr...
# 51  https://www.khanacademy.org/math/cc-seventh-gr...
# 52  https://www.khanacademy.org/math/cc-eighth-gra...
# 53  https://www.khanacademy.org/math/cc-eighth-gra...
# 54  https://www.khanacademy.org/math/cc-eighth-gra...
# 55  https://www.khanacademy.org/math/cc-eighth-gra...
# 56  https://www.khanacademy.org/math/cc-eighth-gra...

# %% [markdown]
# # IXL的数据汇总

# %%
ixl_All_data = pd.read_excel('ixl.xlsx','ixl',index_col=0)

# %%
ixl_All_data['gaede-subject'].value_counts()
# Out:
# Fifth grade math      442
# Third grade math      403
# Sixth grade math      387
# Fourth grade math     374
# Seventh grade math    355
# Eighth grade math     347
# Algebra 1             341
# Algebra 2             338
# Second grade math     307
# Precalculus           271
# First grade math      254
# Geometry              252
# Kindergarten math     228
# Calculus               98
# Pre-K math             91
# Name: gaede-subject, dtype: int64

# %%
grade_list = ['First grade math','Second grade math','Third grade math','Fourth grade math','Fifth grade math','Sixth grade math','Seventh grade math','Eighth grade math']
grade_num_list = [1,2,3,4,5,6,7,8]

# %%
fina_ixl_data = ixl_All_data[ixl_All_data.columns[1:]]
fina_ixl_data.columns = ['course_garde','content_label','course_name','course_url']

# %%
fina_ixl_data['subject'] = 'math'
fina_ixl_data.head()
# Out:
#     course_garde                 content_label                 course_name  \
# id
# 547   Pre-K math  Numbers and counting up to 3        Count dots - up to 3
# 548   Pre-K math  Numbers and counting up to 3    Learn to count - up to 3
# 549   Pre-K math  Numbers and counting up to 3    Count pictures - up to 3
# 550   Pre-K math  Numbers and counting up to 3  Identify numbers - up to 3
# 551   Pre-K math  Numbers and counting up to 3      Count shapes - up to 3
#
#                                             course_url subject
# id
# 547  https://www.ixl.com/math/pre-k/count-dots-up-to-3    math
# 548  https://www.ixl.com/math/pre-k/learn-to-count-...    math
# 549  https://www.ixl.com/math/pre-k/count-pictures-...    math
# 550  https://www.ixl.com/math/pre-k/identify-number...    math
# 551  https://www.ixl.com/math/pre-k/count-shapes-up...    math

# %%
final_data = pd.DataFrame(columns=['course_name','course_garde','subject','content_label','course_introduction','course_url'])
for one_i in fina_ixl_data.index:
    one = fina_ixl_data.loc[one_i]
    if one['course_garde'] in grade_list:
        one['course_garde'] = grade_num_list[grade_list.index(one['course_garde'])]
        final_data = final_data.append(one)

# %%
final_data
# Out:
#                                           course_name course_garde subject  \
# 866                             Skip-counting by tens            2    math
# 867                             Skip-counting by twos            2    math
# 868                            Skip-counting by fives            2    math
# 869                   Skip-counting by fives and tens            2    math
# 870            Skip-counting by twos, fives, and tens            2    math
# ...                                               ...          ...     ...
# 4409         Compound events: find the number of sums            6    math
# 4410        Identify dependent and independent events            6    math
# 4411  Probability of dependent and independent events            6    math
# 4412                                       Factorials            6    math
# 4413                                     Permutations            6    math
#
#                      content_label course_introduction  \
# 866   Counting and number patterns                 NaN
# 867   Counting and number patterns                 NaN
# 868   Counting and number patterns                 NaN
# 869   Counting and number patterns                 NaN
# 870   Counting and number patterns                 NaN
# ...                            ...                 ...
# 4409                   Probability                 NaN
# 4410                   Probability                 NaN
# 4411                   Probability                 NaN
# 4412                   Probability                 NaN
# 4413                   Probability                 NaN
#
#                                              course_url
# 866   https://www.ixl.com/math/grade-2/skip-counting...
# 867   https://www.ixl.com/math/grade-2/skip-counting...
# 868   https://www.ixl.com/math/grade-2/skip-counting...
# 869   https://www.ixl.com/math/grade-2/skip-counting...
# 870   https://www.ixl.com/math/grade-2/skip-counting...
# ...                                                 ...
# 4409  https://www.ixl.com/math/grade-6/compound-even...
# 4410  https://www.ixl.com/math/grade-6/identify-depe...
# 4411  https://www.ixl.com/math/grade-6/probability-o...
# 4412        https://www.ixl.com/math/grade-6/factorials
# 4413      https://www.ixl.com/math/grade-6/permutations
#
# [2869 rows x 6 columns]

# %%
final_data.idnex = list(range(len(final_data)))
# Out:
# c:\users\xingy\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
len(final_data)
# Out:
# 4918

# %%
final_data
# Out:
#                                             course_name course_garde subject  \
# 0                                              Counting          all    math
# 1                        Addition and subtraction intro          all    math
# 2                       Place value (tens and hundreds)          all    math
# 3                    Addition and subtraction within 20          all    math
# 4                   Addition and subtraction within 100          all    math
# ...                                                 ...          ...     ...
# 5030     Find confidence intervals for population means  Precalculus    math
# 5031  Find confidence intervals for population propo...  Precalculus    math
# 5032  Interpret confidence intervals for population ...  Precalculus    math
# 5033                                  Experiment design  Precalculus    math
# 5034  Analyze the results of an experiment using sim...  Precalculus    math
#
#      content_label course_introduction  \
# 0       early-math                null
# 1       early-math                null
# 2       early-math                null
# 3       early-math                null
# 4       early-math                null
# ...            ...                 ...
# 5030    Statistics                 NaN
# 5031    Statistics                 NaN
# 5032    Statistics                 NaN
# 5033    Statistics                 NaN
# 5034    Statistics                 NaN
#
#                                              course_url
# 0     https://www.khanacademy.org/math/early-math/cc...
# 1     https://www.khanacademy.org/math/early-math/cc...
# 2     https://www.khanacademy.org/math/early-math/cc...
# 3     https://www.khanacademy.org/math/early-math/cc...
# 4     https://www.khanacademy.org/math/early-math/cc...
# ...                                                 ...
# 5030  https://www.ixl.com/math/precalculus/find-conf...
# 5031  https://www.ixl.com/math/precalculus/find-conf...
# 5032  https://www.ixl.com/math/precalculus/interpret...
# 5033  https://www.ixl.com/math/precalculus/experimen...
# 5034  https://www.ixl.com/math/precalculus/analyze-t...
#
# [4918 rows x 6 columns]

# %%
final_data.to_excel('所有数据.xlsx')

# %%
my_data  = pd.read_excel('所有数据.xlsx','Sheet1',index_col=0)
my_data.head()
# Out:
#                            course_name course_garde subject content_label  \
# 0                             Counting          all    math    early-math
# 1       Addition and subtraction intro          all    math    early-math
# 2      Place value (tens and hundreds)          all    math    early-math
# 3   Addition and subtraction within 20          all    math    early-math
# 4  Addition and subtraction within 100          all    math    early-math
#
#    course_introduction                                         course_url
# 0                  NaN  https://www.khanacademy.org/math/early-math/cc...
# 1                  NaN  https://www.khanacademy.org/math/early-math/cc...
# 2                  NaN  https://www.khanacademy.org/math/early-math/cc...
# 3                  NaN  https://www.khanacademy.org/math/early-math/cc...
# 4                  NaN  https://www.khanacademy.org/math/early-math/cc...

# %%
my_data['course_garde'].value_counts()
# Out:
# Fifth grade math      442
# all                   430
# Third grade math      403
# Sixth grade math      387
# Fourth grade math     374
# Seventh grade math    355
# Eighth grade math     347
# Algebra 1             341
# Algebra 2             338
# Second grade math     307
# Precalculus           271
# First grade math      254
# Geometry              252
# Kindergarten math     228
# Calculus               98
# Pre-K math             91
# Name: course_garde, dtype: int64
